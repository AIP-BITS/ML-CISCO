# %%
Variables
Operators - +*/,//,**,%
# Out:
# Hello World

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
3%2
# Out:
# 1

# %%
# Data Types
int
float
bool
str

# %%
# Data Structures
# Tuple
# list
# Dict
# Set

# %%
# If then Else

# %%
# Loops
  # - For
  # - While
  # - do while x

# %%
# List, Dict and Set Comprehension

# %%
(3,4),1

# %%
(9+16)**0.5 -1
# Out:
# 4.0

# %%
import math

# %%
math.hypot(3,4)
# Out:
# 5.0

# %%
from math. import hypot as h

# %%
h(3,4)
# Out:
# 5.0

# %%
# Pandas
# Numpy
# Matplotlib
# Seaborn

# %%
dist = [5,4,7,8,9]
speed = [2,1,3,4,2]

# %%
time = dist/speed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7aad64bb0102> in <module>()
# ----> 1 time = dist/speed
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
import numpy as np

# %%
dist = np.array([5,4,7,8,9])
speed = np.array([2,1,3,4,2])
time=dist/speed

# %%
print(time)
# Out:
# [2.5        4.         2.33333333 2.         4.5       ]
